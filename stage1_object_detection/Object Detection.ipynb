# %%
#gadi yohanan
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#Check if everything is installed
# !yolo -h
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 897, in entrypoint
#     special[a.lower()]()
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 860, in <lambda>
#     "hub": lambda: handle_yolo_hub(args[1:]),
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 581, in handle_yolo_hub
#     if args[0] == "login":
#        ~~~~^^^
# IndexError: list index out of range
# ...

# %%
# Create a file system link
# !ln -s /content/drive/MyDrive/yolov11_atk_train/dataset /content/dataset

# %%
# Model training
# !yolo train \
  model=yolo11n.pt \
  data=/content/dataset/data.yaml \
  imgsz=640 \
  epochs=50 \
  batch=16 \
  project=/content/drive/MyDrive/yolov11_atk_train/output \
  name=atk_yolov11 \
  exist_ok
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 66.2MB/s]
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
#We will run a training on the most successful model that was BEST.PT
# !yolo predict \
  model=/content/drive/MyDrive/yolov11_atk_train/output/atk_yolov11/weights/best.pt \
  source=/content/drive/MyDrive/yolov11_atk_train/dataset/valid/images \
  imgsz=640 \
  conf=0.25 \
  save=True

# Copying the results to the drive:
# !cp -r /content/runs/predict /content/drive/MyDrive/yolov11_atk_train/predictions
# Out:
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/241 /content/drive/MyDrive/yolov11_atk_train/dataset/valid/images/434-img_-Neg-_jpg.rf.41913c99db963115279e1eb863fa2572.jpg: 640x640 1 0, 12.9ms
# image 2/241 /content/drive/MyDrive/yolov11_atk_train/dataset/valid/images/513-img_-Neg-_jpg.rf.4cf74f999cf84af5d741ff10722fe727.jpg: 640x640 1 0, 10.9ms
# image 3/241 /content/drive/MyDrive/yolov11_atk_train/dataset/valid/images/539-img_-Neg-_jpg.rf.6e869201b8e3361cbd5df2d587eb942d.jpg: 640x640 1 0, 12.9ms
# image 4/241 /content/drive/MyDrive/yolov11_atk_train/dataset/valid/images/575-img_-Positive-_jpg.rf.446b157bdaecafe4c611060a47368167.jpg: 640x640 1 1, 11.4ms
# image 5/241 /content/drive/MyDrive/yolov11_atk_train/dataset/valid/images/59-img_-Neggesr-_jpg.rf.97209271e700d66e7cb6b255b6bdaa92.jpg: 640x640 1 0, 12.1ms
# ...
